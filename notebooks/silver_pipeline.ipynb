# %%
from src.silver.crm.silver_crm_cust_info import run_pipeline
from src.silver.crm.silver_crm_prd_info import run_pipeline_silver_crm_prd_info
from src.silver.crm.silver_crm_sales_details import run_pipeline_crm_sales_details
from src.silver.erp.silver_erp_cust_az12 import run_pipeline_erp_cust_az12
from src.silver.erp.silver_erp_loc_a101 import run_pipeline_erp_loc_a101
from src.silver.erp.silver_erp_px_cat_g1v2 import run_pipeline_erp_px_cat_g1v2

# %%
spark.sql(f"USE CATALOG `databricks-project`")

# %%
#Triggering the pipeline for crm_cust_info
run_pipeline(spark)

# %%
#Triggering the pipeline for crm_prd_info
run_pipeline_silver_crm_prd_info(spark)

# %%
#Triggering the pipeline for crm_sales_details
run_pipeline_crm_sales_details(spark)

# %%
#Triggering the pipeline for erp_cust_az12
run_pipeline_erp_cust_az12(spark)

# %%
#Triggering the pipeline for erp_loc_a10
run_pipeline_erp_loc_a101(spark)

# %%
#Triggering the pipeline for erp_px_cat_g1v2
run_pipeline_erp_px_cat_g1v2(spark)
