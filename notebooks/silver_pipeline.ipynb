# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/crm/silver_crm_cust_info"

# %%
#Triggering the pipeline for crm_cust_info
run_pipeline()

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/crm/silver_crm_prd_info"

# %%
#Triggering the pipeline for crm_prd_info
run_pipeline_silver_crm_prd_info()

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/crm/silver_crm_sales_details"

# %%
#Triggering the pipeline for crm_sales_details
run_pipeline_crm_sales_details()

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/erp/silver_erp_cust_az12"

# %%
#Triggering the pipeline for erp_cust_az12
run_pipeline_erp_cust_az12()

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/erp/silver_erp_loc_a101"

# %%
#Triggering the pipeline for erp_loc_a10
run_pipeline_erp_loc_a101()

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/silver/erp/silver_erp_px_cat_g1v2"

# %%
#Triggering the pipeline for erp_px_cat_g1v2
run_pipeline_erp_px_cat_g1v2()

# %%
# %sql
select * from `databricks-project`.silver.erp_px_cat_g1v2 limit 10
