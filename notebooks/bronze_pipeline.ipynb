# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/bronze/bronze_logic"

# %%
from config.bronze_config import INGESTION_CONFIG
run_bronze_ingestion(spark, INGESTION_CONFIG)
