# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/gold/gold_dim_customers"

# %%
spark.sql(f"USE CATALOG `databricks-project`")

# %%
#Triggering the dim_customers
run_dim_customers(spark)

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/gold/gold_dim_products"

# %%
#Triggering the dim_products
run_dim_products(spark)

# %%
# %run "/Workspace/Users/tiwarivibhu193@gmail.com/Databricks-PySpark-DataWarehouse-Project/src/gold/gold_facts_sales"

# %%
#Triggering the facts_sales
run_facts_sales(spark)

# %%
# %sql
select * from `databricks-project`.gold.fact_sales
